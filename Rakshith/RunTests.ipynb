# %% [markdown]
# [
# # Function tests\n",
#     "8 functions are defined for the \"MapMaker\" notebook. They are tested individually to determine if they work well and return the results we anticipate."
#    ]

# %%
from src import my_functions

# %%
#downloading the data might take longer than expected during the time the test code is run\n

# %%
! pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/jupyter-u7477538/EMSC-4033-2022-assignment-Group2/Rakshith
# plugins: anyio-3.5.0
# collected 5 items
#
# tests/test_functions.py .FF..                                            [100%]
#
# =================================== FAILURES ===================================
# ___________________________ test_download_point_data ___________________________
#
# self = <http.client.HTTPResponse object at 0x7fbb0f02a2b0>
#
#     def _get_chunk_left(self):
#         # return self.chunk_left, reading a new chunk if necessary.
#         # chunk_left == 0: at the end of the current chunk, need to close it
#         # chunk_left == None: No current chunk, should read next.
#         # This function returns non-zero or None if the last chunk has
#         # been read.
#         chunk_left = self.chunk_left
#         if not chunk_left: # Can be 0 or None
#             if chunk_left is not None:
#                 # We are at the end of chunk, discard chunk end
#                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#             try:
# >               chunk_left = self._read_next_chunk_size()
#
# /opt/tljh/user/lib/python3.9/http/client.py:559:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <http.client.HTTPResponse object at 0x7fbb0f02a2b0>
#
#     def _read_next_chunk_size(self):
#         # Read the next chunk size from the file
#         line = self.fp.readline(_MAXLINE + 1)
#         if len(line) > _MAXLINE:
#             raise LineTooLong("chunk size")
#         i = line.find(b";")
#         if i >= 0:
#             line = line[:i] # strip chunk-extensions
#         try:
# >           return int(line, 16)
# E           ValueError: invalid literal for int() with base 16: b''
#
# /opt/tljh/user/lib/python3.9/http/client.py:526: ValueError
#
# During handling of the above exception, another exception occurred:
#
# self = <http.client.HTTPResponse object at 0x7fbb0f02a2b0>
#
#     def _readall_chunked(self):
#         assert self.chunked != _UNKNOWN
#         value = []
#         try:
#             while True:
# >               chunk_left = self._get_chunk_left()
#
# /opt/tljh/user/lib/python3.9/http/client.py:576:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <http.client.HTTPResponse object at 0x7fbb0f02a2b0>
#
#     def _get_chunk_left(self):
#         # return self.chunk_left, reading a new chunk if necessary.
#         # chunk_left == 0: at the end of the current chunk, need to close it
#         # chunk_left == None: No current chunk, should read next.
#         # This function returns non-zero or None if the last chunk has
#         # been read.
#         chunk_left = self.chunk_left
#         if not chunk_left: # Can be 0 or None
#             if chunk_left is not None:
#                 # We are at the end of chunk, discard chunk end
#                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#             try:
#                 chunk_left = self._read_next_chunk_size()
#             except ValueError:
# >               raise IncompleteRead(b'')
# E               http.client.IncompleteRead: IncompleteRead(0 bytes read)
#
# /opt/tljh/user/lib/python3.9/http/client.py:561: IncompleteRead
#
# During handling of the above exception, another exception occurred:
#
# my_eq_type = <class 'numpy.ndarray'>, my_eq_size = 4
#
#     def test_download_point_data(my_eq_type = np.ndarray, my_eq_size = 4):
#         # Test with type and test if the array do has correct shape/features
#
#         lat0 =  30  ; lat1 = 40
#         lon0 =  125; lon1 = 135
#         map_extent = [lon0, lon1, lat0, lat1]
#
# >       eq = download_point_data(map_extent)
#
# tests/test_functions.py:65:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# tests/src/my_functions.py:133: in download_point_data
#     cat = client.get_events(starttime = from_time, endtime = to_time,
# /opt/tljh/user/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:548: in get_events
#     data_stream = self._download(url)
# /opt/tljh/user/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1415: in _download
#     code, data = download_url(
# /opt/tljh/user/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1847: in download_url
#     buf = io.BytesIO(url_obj.read())
# /opt/tljh/user/lib/python3.9/http/client.py:469: in read
#     return self._readall_chunked()
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <http.client.HTTPResponse object at 0x7fbb0f02a2b0>
#
#     def _readall_chunked(self):
#         assert self.chunked != _UNKNOWN
#         value = []
#         try:
#             while True:
#                 chunk_left = self._get_chunk_left()
#                 if chunk_left is None:
#                     break
#                 value.append(self._safe_read(chunk_left))
#                 self.chunk_left = 0
#             return b''.join(value)
#         except IncompleteRead:
# >           raise IncompleteRead(b''.join(value))
# E           http.client.IncompleteRead: IncompleteRead(172129 bytes read)
#
# /opt/tljh/user/lib/python3.9/http/client.py:583: IncompleteRead
# ______________________________ test_my_point_data ______________________________
#
# self = <http.client.HTTPResponse object at 0x7fbb0e6d9b20>
#
#     def _get_chunk_left(self):
#         # return self.chunk_left, reading a new chunk if necessary.
#         # chunk_left == 0: at the end of the current chunk, need to close it
#         # chunk_left == None: No current chunk, should read next.
#         # This function returns non-zero or None if the last chunk has
#         # been read.
#         chunk_left = self.chunk_left
#         if not chunk_left: # Can be 0 or None
#             if chunk_left is not None:
#                 # We are at the end of chunk, discard chunk end
#                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#             try:
# >               chunk_left = self._read_next_chunk_size()
#
# /opt/tljh/user/lib/python3.9/http/client.py:559:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <http.client.HTTPResponse object at 0x7fbb0e6d9b20>
#
#     def _read_next_chunk_size(self):
#         # Read the next chunk size from the file
#         line = self.fp.readline(_MAXLINE + 1)
#         if len(line) > _MAXLINE:
#             raise LineTooLong("chunk size")
#         i = line.find(b";")
#         if i >= 0:
#             line = line[:i] # strip chunk-extensions
#         try:
# >           return int(line, 16)
# E           ValueError: invalid literal for int() with base 16: b''
#
# /opt/tljh/user/lib/python3.9/http/client.py:526: ValueError
#
# During handling of the above exception, another exception occurred:
#
# self = <http.client.HTTPResponse object at 0x7fbb0e6d9b20>
#
#     def _readall_chunked(self):
#         assert self.chunked != _UNKNOWN
#         value = []
#         try:
#             while True:
# >               chunk_left = self._get_chunk_left()
#
# /opt/tljh/user/lib/python3.9/http/client.py:576:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <http.client.HTTPResponse object at 0x7fbb0e6d9b20>
#
#     def _get_chunk_left(self):
#         # return self.chunk_left, reading a new chunk if necessary.
#         # chunk_left == 0: at the end of the current chunk, need to close it
#         # chunk_left == None: No current chunk, should read next.
#         # This function returns non-zero or None if the last chunk has
#         # been read.
#         chunk_left = self.chunk_left
#         if not chunk_left: # Can be 0 or None
#             if chunk_left is not None:
#                 # We are at the end of chunk, discard chunk end
#                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#             try:
#                 chunk_left = self._read_next_chunk_size()
#             except ValueError:
# >               raise IncompleteRead(b'')
# E               http.client.IncompleteRead: IncompleteRead(0 bytes read)
#
# /opt/tljh/user/lib/python3.9/http/client.py:561: IncompleteRead
#
# During handling of the above exception, another exception occurred:
#
# type_my_element = <class 'numpy.bool_'>
#
#     def test_my_point_data(type_my_element = np.bool_):
#         # Test with the type of each element in the array
#
#         lat0 =  -20  ; lat1 = 55
#         lon0 =  -90; lon1 = -160
#         map_extent = [lon0, lon1, lat0, lat1]
#
# >       point_data = my_point_data(map_extent)
#
# tests/test_functions.py:81:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# tests/src/my_functions.py:160: in my_point_data
#     data = download_point_data(region)
# tests/src/my_functions.py:133: in download_point_data
#     cat = client.get_events(starttime = from_time, endtime = to_time,
# /opt/tljh/user/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:548: in get_events
#     data_stream = self._download(url)
# /opt/tljh/user/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1415: in _download
#     code, data = download_url(
# /opt/tljh/user/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1847: in download_url
#     buf = io.BytesIO(url_obj.read())
# /opt/tljh/user/lib/python3.9/http/client.py:469: in read
#     return self._readall_chunked()
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <http.client.HTTPResponse object at 0x7fbb0e6d9b20>
#
#     def _readall_chunked(self):
#         assert self.chunked != _UNKNOWN
#         value = []
#         try:
#             while True:
#                 chunk_left = self._get_chunk_left()
#                 if chunk_left is None:
#                     break
#                 value.append(self._safe_read(chunk_left))
#                 self.chunk_left = 0
#             return b''.join(value)
#         except IncompleteRead:
# >           raise IncompleteRead(b''.join(value))
# E           http.client.IncompleteRead: IncompleteRead(174904 bytes read)
#
# /opt/tljh/user/lib/python3.9/http/client.py:583: IncompleteRead
# =========================== short test summary info ============================
# FAILED tests/test_functions.py::test_download_point_data - http.client.Incomp...
# FAILED tests/test_functions.py::test_my_point_data - http.client.IncompleteRe...
# =================== 2 failed, 3 passed in 105.26s (0:01:45) ====================
